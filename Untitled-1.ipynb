# %%
from my_graph_partitioning import *
import dimod

# %%
sampler = dimod.SimulatedAnnealingSampler()
sampler.sample()

# %%
g = GraphPartitioning.Ring(4)
g.analyse(name='cycle',sa=sampler,num_reads=100, difference_func=lambda n,d:20)
print(g.sampleset)
# Out:
# condtiton failed by: 0.0
#    s[0] s[1] s[2] s[3] energy num_oc.
# 0    -1   -1   +1   +1    4.0       1
# 1    +1   -1   -1   +1    4.0       1
# 2    -1   -1   +1   +1    4.0       1
# 3    +1   -1   -1   +1    4.0       1
# 5    +1   +1   -1   -1    4.0       1
# 6    -1   +1   +1   -1    4.0       1
# 8    -1   -1   +1   +1    4.0       1
# 10   +1   -1   -1   +1    4.0       1
# 11   +1   -1   -1   +1    4.0       1
# 12   -1   -1   +1   +1    4.0       1
# 13   +1   +1   -1   -1    4.0       1
# 14   -1   -1   +1   +1    4.0       1
# 15   +1   +1   -1   -1    4.0       1
# 16   -1   -1   +1   +1    4.0       1
# 17   -1   +1   +1   -1    4.0       1
# 18   +1   +1   -1   -1    4.0       1
# 19   -1   -1   +1   +1    4.0       1
# 20   +1   +1   -1   -1    4.0       1
# 21   -1   -1   +1   +1    4.0       1
# 22   +1   -1   -1   +1    4.0       1
# 24   +1   -1   -1   +1    4.0       1
# 25   -1   +1   +1   -1    4.0       1
# 26   -1   +1   +1   -1    4.0       1
# ...
